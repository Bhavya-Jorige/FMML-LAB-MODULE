# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhavya-Jorige/FMML-LAB-MODULE/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-26 14:36:19--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   133MB/s    in 0.5s
#
# 2024-03-26 14:36:19 (133 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 21527   0908.2284v1  We introduce a new nearest-prototype classifie...  stat
# 34224   1407.3636v1  In this paper we analyse the selectivity measu...    cs
# 26587  1611.03968v4  One object class may show large variations due...    cs
# 3785   1508.05514v1  We propose a greedy mixture reduction algorith...  stat
# 29299  1709.00443v1  Non-frontal lip views contain useful informati...    cs
# ...             ...                                                ...   ...
# 16807  1706.02861v3  Endowing a chatbot with personality or an iden...    cs
# 22550  1611.04790v1  The ability to track a moving vehicle is of cr...  stat
# 1330    1412.6115v1  Deep convolutional neural networks (CNN) has b...    cs
# 2516   1507.00353v1  The true online TD({\lambda}) algorithm has re...    cs
# 6414   1701.05265v1  Sum-product networks have recently emerged as ...  stat
#
#                                                    title  year  \
# 21527  Classification by Set Cover: The Prototype Vec...  2009
# 34224  Toward Network-based Keyword Extraction from M...  2014
# 26587  Learning Scene-specific Object Detectors Based...  2016
# 3785   Gaussian Mixture Reduction Using Reverse Kullb...  2015
# 29299                   End-to-End Multi-View Lipreading  2017
# ...                                                  ...   ...
# 16807  Assigning personality/identity to a chatting m...  2017
# 22550  Improved Particle Filters for Vehicle Localisa...  2016
# 1330   Compressing Deep Convolutional Networks using ...  2014
# 2516        An Empirical Evaluation of True Online TD(λ)  2015
# 6414   Online Structure Learning for Sum-Product Netw...  2017
#
#                                                 keywords
# 21527  [introduce, prototype, classifier, prototype, ...
# 34224  [selectivity, calculated, automatic, extractio...
# 26587  [variations, illuminations, backgrounds, viewp...
# 3785   [reduction, algorithm, components, divergence,...
# 29299  [information, performance, lipreading, lipread...
# ...                                                  ...
# 16807  [personality, challenging, realistic, conversa...
# 22550  [importance, applications, approached, importa...
# 1330   [convolutional, promising, recognition, repeat...
# 2516   [algorithm, universal, replacement, algorithm,...
# 6414   [attractive, representation, semantics, probab...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 21527    [introduce, prototype, classifier, prototype, ...
# 34224    [selectivity, calculated, automatic, extractio...
# 26587    [variations, illuminations, backgrounds, viewp...
# 3785     [reduction, algorithm, components, divergence,...
# 29299    [information, performance, lipreading, lipread...
#                                ...
# 22114    [introduced, estimation, generative, reduction...
# 5981     [optimization, effective, methodology, optimiz...
# 25622    [segmentation, autosomal, polycystic, insuffic...
# 23040    [measuring, divergence, distributions, essenti...
# 28992    [interpret, environment, applications, resolut...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8813 words.
# Out of those 4604 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="97a0d86d-5cbf-4fc7-bd07-e4c89369e20c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("97a0d86d-5cbf-4fc7-bd07-e4c89369e20c")) {                    Plotly.newPlot(                        "97a0d86d-5cbf-4fc7-bd07-e4c89369e20c",                        [{"x":["classification","compatible","optimization","euclidean","approximating","outperforms","demonstrate","algorithms","relatively","combinatorial","prototype","introduce","interpretable","classifier","successful","situations","dissimilarity","additionally","strengths","representative","retaining","highlights","underlying","desirable","represented","documents","filtering","according","candidates","calculated","established","extraction","selectivity","different","collected","occurrence","occurring","promising","extracting","automatic","centrality","traditional","labelling","autonomous","conveniently","partition","variations","approaches","unconstrained","obviously","supervised","detection","particular","illuminations","difficult","descriptor","supervision","progressively","triggered","viewpoints","appearance","representations","consequently","comparable","individual","generative","environments","discriminative","surveillance","replicated","framework","detectors","initialized","performance","direction","applications","conditions","backgrounds","remarkably","algorithm","optimized","hierarchical","complexity","preserving","divergence","efficient","components","capability","restricted","computationally","analytical","simulated","computational","reduction","approximations","intractability","circumvent","alternative","operations","numerical","improvement","simultaneously","including","databases","significantly","identical","consequence","respectively","bidirectional","knowledge","achieving","information","outperform","jackknife","nonparametric","estimation","uncertainties","estimated","stochastic","distribution","estimates","measurement","constructed","described","uncertainty","accordingly","statistical","assumptions","nonlinear","estimator","construct","manuscript","effectively","evolutionary","optimising","simulation","intelligence","ecosystem","themselves","application","functionality","investigate","optimisation","intelligent","ecosystems","distributed","selection","counterpart","marginally","recognition","contribute","technology","ecological","mechanism","biological","operation","theoretical","boltzmann","approximation","probability","generalize","approximate","arbitrarily","vanishing","exceeding","arbitrary","tolerance","universal","attractive","attention","utterances","transcribing","retrieving","containing","unsupervised","importance","applicable","performances","describes","explained","significant","analyzing","distributions","construction","following","represents","determine","polyphonic","realization","processing","carefully","parameters","incorporated","explicitly","stability","experience","limitations","robustness","advantages","researchers"],"y":[524,13,315,36,14,254,547,601,63,35,22,331,27,156,66,48,7,66,23,27,8,11,104,40,88,72,84,93,26,26,51,150,3,754,79,28,13,107,73,202,7,165,11,49,4,26,84,464,24,4,183,377,284,2,157,21,70,16,8,11,87,233,38,88,129,136,71,104,28,3,533,34,11,863,61,427,128,8,12,815,52,108,218,51,23,353,104,47,48,72,18,47,295,101,33,3,6,95,72,82,116,101,228,58,263,11,29,90,23,354,81,729,91,0,14,189,12,56,132,212,61,24,66,61,71,12,179,59,47,27,95,7,130,67,6,78,97,2,21,245,15,156,17,48,3,100,167,18,5,379,35,59,2,112,48,46,156,17,115,159,57,97,18,9,7,99,8,30,25,182,20,3,16,70,154,95,47,51,73,15,231,63,120,66,76,63,76,3,5,304,29,239,19,66,34,32,68,118,81,76],"type":"bar"},{"x":["classification","compatible","optimization","euclidean","approximating","out ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4604,), (4604, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8008333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Halfspaces</span> <span style=''>and</span> <span style=''>Neural</span> <span style=''>Networks</span> <span style=''>with</span> <span style=''>Random</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Initialization</span> <br/><br/><span style=''>We</span> <span style=''>study</span> <span style=''>non</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>empirical</span> <span style=''>risk</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimization</span> <span style=''>for</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>halfspaces</span> <span style=''>and</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>For</span> <span style=''>loss</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>that</span> <span style=''>are</span> <span style=''>L</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Lipschitz</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>continuous</span> <span style=''>we</span> <span style=''>present</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>to</span> <span style=''>learn</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>halfspaces</span> <span style=''>and</span> <span style=''>multi</span> <span style=''>layer</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>that</span> <span style=''>achieve</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>arbitrarily</span> <span style=''>small</span> <span style=''>excess</span> <span style=''>risk</span> <span style=''>epsilon0</span> <span style=''>The</span> <span style=''>time</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>polynomial</span> <span style=''>in</span> <span style=''>the</span> <span style=''>input</span> <span style='background-color:rgba(255, 0, 0, 0.3990147783251232);'>dimension</span> <span style=''>d</span> <span style=''>and</span> <span style=''>the</span> <span style=''>sample</span> <span style=''>size</span> <span style=''>n</span> <span style=''>but</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exponential</span> <span style=''>in</span> <span style=''>the</span> <span style=''>quantity</span> <span style=''>(Lepsilon2)log(Lepsilon)</span> <span style=''>These</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>run</span> <span style=''>multiple</span> <span style=''>rounds</span> <span style=''>of</span> <span style=''>random</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>initialization</span> <span style=''>followed</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>arbitrary</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>steps</span> <span style=''>We</span> <span style=''>further</span> <span style=''>show</span> <span style=''>that</span> <span style=''>if</span> <span style=''>the</span> <span style=''>data</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>separable</span> <span style=''>by</span> <span style=''>some</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>with</span> <span style=''>constant</span> <span style=''>margin</span> <span style=''>gamma0</span> <span style=''>then</span> <span style=''>there</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>polynomial</span> <span style=''>time</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>learning</span> <span style=''>a</span> <span style=''>neural</span> <sp ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Seeded</span> <span style=''>Graph</span> <span style=''>Matching</span> <br/><br/><span style=''>Given</span> <span style=''>two</span> <span style=''>graphs</span> <span style=''>the</span> <span style=''>graph</span> <span style=''>matching</span> <span style=''>problem</span> <span style=''>is</span> <span style=''>to</span> <span style=''>align</span> <span style=''>the</span> <span style=''>two</span> <span style=''>vertex</span> <span style=''>sets</span> <span style=''>so</span> <span style=''>as</span> <span style=''>to</span> <span style=''>minimize</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>adjacency</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>disagreements</span> <span style=''>between</span> <span style=''>the</span> <span style=''>two</span> <span style=''>graphs</span> <span style=''>The</span> <span style=''>seeded</span> <span style=''>graph</span> <span style=''>matching</span> <span style=''>problem</span> <span style=''>is</span> <span style=''>the</span> <span style=''>graph</span> <span style=''>matching</span> <span style=''>problem</span> <span style=''>when</span> <span style=''>we</span> <span style=''>are</span> <span style=''>first</span> <span style=''>given</span> <span style=''>a</span> <span style=''>partial</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>alignment</span> <span style=''>that</span> <span style=''>we</span> <span style=''>are</span> <span style=''>tasked</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>completing</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>modify</span> <span style=''>the</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximate</span> <span style=''>graph</span> <span style=''>matching</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>FAQ</span> <span style=''>of</span> <span style=''>Vogelstein</span> <span style=''>et</span> <span style=''>al</span> <span style=''>(2015)</span> <span style=''>to</span> <span style=''>make</span> <span style=''>it</span> <span style=''>a</span> <span style=''>fast</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximate</span> <span style=''>seeded</span> <span style=''>graph</span> <span style=''>matching</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>adapt</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applicability</span> <span style=''>to</span> <span style=''>include</span> <span style=''>graphs</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>differently</span> <span style=''>sized</span> <span style=''>vertex</span> <span style=''>sets</span> <span style=''>and</span> <span style=''>extend</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>so</span> <span style=''>as</span> <span style=''>to</span> <span style=''>provide</span> <span style=''>for</span> <span style=''>each</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>individual</span> <span style=''>vertex</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nomination</span> <span style=''>list</span> <span style=''>of</span> <span style=''>likely</span> <span style=''>matches</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effectiveness</span> <span style=''>of</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Sketching</span> <span style=''>and</span> <span style=''>Neural</span> <span style=''>Networks</span> <br/><br/><span style=''>High</span> <span style='background-color:rgba(255, 0, 0, 0.4014598540145986);'>dimensional</span> <span style=''>sparse</span> <span style=''>data</span> <span style=''>present</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computational</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3021442495126706);'>statistical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>challenges</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>supervised</span> <span style=''>learning</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>compact</span> <span style=''>linear</span> <span style=''>sketches</span> <span style=''>for</span> <span style=''>reducing</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dimensionality</span> <span style=''>of</span> <span style=''>the</span> <span style=''>input</span> <span style=''>followed</span> <span style=''>by</span> <span style=''>a</span> <span style=''>single</span> <span style=''>layer</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>any</span> <span style=''>sparse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>polynomial</span> <span style=''>function</span> <span style=''>can</span> <span style=''>be</span> <span style=''>computed</span> <span style=''>on</span> <span style=''>nearly</span> <span style=''>all</span> <span style=''>sparse</span> <span style=''>binary</span> <span style=''>vectors</span> <span style=''>by</span> <span style=''>a</span> <span style=''>single</span> <span style=''>layer</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>that</span> <span style=''>takes</span> <span style=''>a</span> <span style=''>compact</span> <span style=''>sketch</span> <span style=''>of</span> <span style=''>the</span> <span style=''>vector</span> <span style=''>as</span> <span style=''>input</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Consequently</span> <span style=''>when</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>sparse</span> <span style=''>binary</span> <span style=''>vectors</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximately</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>separable</span> <span style=''>using</span> <span style=''>a</span> <span style=''>sparse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>polynomial</span> <span style=''>there</span> <span style=''>exists</span> <span style=''>a</span> <span style=''>single</span> <span style=''>layer</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>that</span> <span style=''>takes</span> <span style=''>a</span> <span style=''>short</span> <span style=''>sketch</span> <span style=''>as</span> <span style=''>input</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333326);'>correctly</span> <span style='background-color:rgba(0, 255, 0, 0.44444444444444453);'>classifies</span> <span style=''>nearly</span> <span style=''>all</span> <span style=''>the</span> <span style=''>points</span> <span style=''>Previous</span> <span style=''>work</span> <span style=''>has</span> <span style=''>proposed</span> <span style=''>using</span> <span style=''>sketches</span> <span style=''>to</span> <span style=''>reduce</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dimensionality</span> <span style=''>while</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>preserving</span> <span style=''>the</span> <span style='background-color:rgba(0, 255 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Geometric</span> <span style=''>Mean</span> <span style=''>Metric</span> <span style=''>Learning</span> <br/><br/><span style=''>We</span> <span style=''>revisit</span> <span style=''>the</span> <span style=''>task</span> <span style=''>of</span> <span style=''>learning</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Euclidean</span> <span style=''>metric</span> <span style=''>from</span> <span style=''>data</span> <span style=''>We</span> <span style=''>approach</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>from</span> <span style=''>first</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>principles</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formulate</span> <span style=''>it</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>surprisingly</span> <span style=''>simple</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>problem</span> <span style=''>Indeed</span> <span style=''>our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulation</span> <span style=''>even</span> <span style=''>admits</span> <span style=''>a</span> <span style=''>closed</span> <span style=''>form</span> <span style=''>solution</span> <span style=''>This</span> <span style=''>solution</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>possesses</span> <span style=''>several</span> <span style=''>very</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>attractive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>(i)</span> <span style=''>an</span> <span style=''>innate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>geometric</span> <span style=''>appeal</span> <span style=''>through</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Riemannian</span> <span style=''>geometry</span> <span style=''>of</span> <span style=''>positive</span> <span style=''>definite</span> <span style=''>matrices</span> <span style=''>(ii)</span> <span style=''>ease</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretability</span> <span style=''>and</span> <span style=''>(iii)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style=''>speed</span> <span style=''>several</span> <span style=''>orders</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>magnitude</span> <span style=''>faster</span> <span style=''>than</span> <span style=''>the</span> <span style=''>widely</span> <span style=''>used</span> <span style=''>LMNN</span> <span style=''>and</span> <span style=''>ITML</span> <span style=''>methods</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Furthermore</span> <span style=''>on</span> <span style=''>standard</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>benchmark</span> <span style=''>datasets</span> <span style=''>our</span> <span style=''>closed</span> <span style=''>form</span> <span style=''>solution</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consistently</span> <span style=''>attains</span> <span style=''>higher</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>accuracy</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.1303106033559443)
# 	processing (0.1085326669046769)
# 	architecture (0.0849696536951089)
# 	experimental (0.135308818279186)
# 	segmentation (0.07604426990360585)
# 	information (0.2602641913602285)
# 	different (0.26918957515173153)
# 	detection (0.13459478757586577)
# 	recognition (0.135308818279186)
# 	convolutional (0.14709032488397)
#
# Some Statistics words are:
# 	convergence (0.12906453226613307)
# 	algorithm (0.3856928464232116)
# 	theoretical (0.15307653826913456)
# 	estimation (0.16508254127063532)
# 	statistical (0.16708354177088544)
# 	variables (0.14907453726863432)
# 	distribution (0.18309154577288644)
# 	inference (0.19009504752376188)
# 	dimensional (0.192096048024012)
# 	regression (0.1950975487743872)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="7702cf2f-c3d9-4017-b19b-0c0b49b23df9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7702cf2f-c3d9-4017-b19b-0c0b49b23df9")) {                    Plotly.newPlot(                        "7702cf2f-c3d9-4017-b19b-0c0b49b23df9",                        [{"x":["classification","compatible","optimization","euclidean","approximating","outperforms","demonstrate","algorithms","relatively","combinatorial","prototype","introduce","interpretable","classifier","successful","situations","dissimilarity","additionally","strengths","representative","retaining","highlights","underlying","desirable","represented","documents","filtering","according","candidates","calculated","established","extraction","selectivity","different","collected","occurrence","occurring","promising","extracting","automatic","centrality","traditional","labelling","autonomous","conveniently","partition","variations","approaches","unconstrained","obviously","supervised","detection","particular","illuminations","difficult","descriptor","supervision","progressively","triggered","viewpoints","appearance","representations","consequently","comparable","individual","generative","environments","discriminative","surveillance","replicated","framework","detectors","initialized","performance","direction","applications","conditions","backgrounds","remarkably","algorithm","optimized","hierarchical","complexity","preserving","divergence","efficient","components","capability","restricted","computationally","analytical","simulated","computational","reduction","approximations","intractability","circumvent","alternative","operations","numerical","improvement","simultaneously","including","databases","significantly","identical","consequence","respectively","bidirectional","knowledge","achieving","information","outperform","jackknife","nonparametric","estimation","uncertainties","estimated","stochastic","distribution","estimates","measurement","constructed","described","uncertainty","accordingly","statistical","assumptions","nonlinear","estimator","construct","manuscript","effectively","evolutionary","optimising","simulation","intelligence","ecosystem","themselves","application","functionality","investigate","optimisation","intelligent","ecosystems","distributed","selection","counterpart","marginally","recognition","contribute","technology","ecological","mechanism","biological","operation","theoretical","boltzmann","approximation","probability","generalize","approximate","arbitrarily","vanishing","exceeding","arbitrary","tolerance","universal","attractive","attention","utterances","transcribing","retrieving","containing","unsupervised","importance","applicable","performances","describes","explained","significant","analyzing","distributions","construction","following","represents","determine","polyphonic","realization","processing","carefully","parameters","incorporated","explicitly","stability","experience","limitations","robustness","advantages","researchers","independently","improving","considerable","convergence","representation","relationships","infeasible","interactions","relationship","subgroups","validated","activitynet","furthermore","captioning","efficiently","computation","understanding","hypothesis","misspecification","bootstrap","generating","sequential","pertinent","procedure","randomized","inflation","inference","practical","experiments","likelihood","monitoring","continuous","morphological","normalization","statistically","variation","conditional","challenge","gazetteers","developed","propositional","annotated","negatively","specifically","identification","expression","normalizer","accuracies","difference","surprisingly","maximization","incentivize","engagement","synthet ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	jackknife
# 	inflation
# 	subsample
# 	methodologically
# 	mislabeled
# 	incoherence
# 	deteriorates
# 	quadrature
# 	integrands
# 	spectrometry
# 	exchangeable
# 	cubically
# 	differentiability
# 	spectrogram
# 	deconvnet
# 	integrable
# 	semiparametric
# 	elucidates
# 	unperturbed
# 	blockmodel
# Some words which never appear in Statistics papers:
# 	illuminations
# 	ecological
# 	transcribing
# 	activitynet
# 	gazetteers
# 	propositional
# 	retrained
# 	translator
# 	reflection
# 	attracting
# 	transducer
# 	pronunciation
# 	resourced
# 	combinatory
# 	prototyping
# 	adaptable
# 	incredible
# 	navigation
# 	instruction
# 	ultrasound

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.066167903354388e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.76
